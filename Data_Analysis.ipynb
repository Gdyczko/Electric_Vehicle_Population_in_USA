# %% [markdown]
# # Importing necessary packages and loading data

# %%
# Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data
df = pd.read_csv("Data/data.csv")

# %%
display(df.head(10))
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year       Make  \
# 0  JTMAB3FV3P     Kitsap    Seabeck    WA      98380.0        2023     TOYOTA
# 1  1N4AZ1CP6J     Kitsap  Bremerton    WA      98312.0        2018     NISSAN
# 2  5YJ3E1EA4L       King    Seattle    WA      98101.0        2020      TESLA
# 3  1N4AZ0CP8E       King    Seattle    WA      98125.0        2014     NISSAN
# 4  1G1FX6S00H   Thurston       Yelm    WA      98597.0        2017  CHEVROLET
# 5  5YJYGDEE5L  Snohomish   Lynnwood    WA      98036.0        2020      TESLA
# 6  KM8S6DA23N     Kitsap    Poulsbo    WA      98370.0        2022    HYUNDAI
# 7  7FCTGAAA1P  Snohomish  Arlington    WA      98223.0        2023     RIVIAN
# 8  5YJYGDEE9L       King       Kent    WA      98031.0        2020      TESLA
# 9  1N4AZ0CP2F       King   Kirkland    WA      98034.0        2015     NISSAN
#
#         Model E.V_Type     CAFV  Electric Range  Base MSRP  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205439 entries, 0 to 205438
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   VIN (1-10)            205439 non-null  object
#  1   County                205436 non-null  object
#  2   City                  205436 non-null  object
#  3   State                 205439 non-null  object
#  4   Postal Code           205436 non-null  float64
#  5   Model Year            205439 non-null  int64
#  6   Make                  205439 non-null  object
#  7   Model                 205438 non-null  object
#  8   E.V_Type              205439 non-null  object
#  9   CAFV                  205439 non-null  object
#  10  Electric Range        205431 non-null  float64
#  11  Base MSRP             205431 non-null  float64
#  12  Legislative District  204997 non-null  float64
#  13  DOL Vehicle ID        205439 non-null  int64
# ...

# %% [markdown]
# we have a empty values in columns:
# County = 3;
# City = 3;
# Postal Code = 3;
# Model = 1;
# Electric Range = 8;
# Base MSRP = 8;
# Legislative District = 442;
# Vehicle Location = 8;
# Electric Utility = 3;
# 2020 Census Tract = 3

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  205436.000000  205439.000000   205431.000000  205431.000000
# mean    98177.971870    2020.960363       52.164342     922.670532
# std      2419.037479       2.989059       88.075859    7761.753602
# min      1731.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 75%     98372.000000    2023.000000       48.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         204997.000000    2.054390e+05       2.054360e+05
# mean              28.970848    2.277156e+08       5.297704e+10
# std               14.910052    7.205737e+07       1.588435e+09
# min                1.000000    4.469000e+03       1.001020e+09
# ...

# %%
df[pd.isna(df["County"])]
# Out:
#         VIN (1-10) County City State  Postal Code  Model Year       Make  \
# 138102  WBAJA9C50K    NaN  NaN    AE          NaN        2019        BMW
# 182254  5YJXCAE24H    NaN  NaN    BC          NaN        2017      TESLA
# 203466  1G1RB6S53J    NaN  NaN    BC          NaN        2018  CHEVROLET
#
#           Model E.V_Type          CAFV  Electric Range  Base MSRP  \
# 138102     530E     PHEV  not eligible            16.0    53400.0
# 182254  MODEL X      BEV         known           200.0        0.0
# 203466     VOLT     PHEV         known            53.0        0.0
#
#         Legislative District  DOL Vehicle ID Vehicle Location  \
# 138102                   NaN       244582593              NaN
# 182254                   NaN       159850029              NaN
# 203466                   NaN       477613216              NaN
#
#        Electric Utility  2020 Census Tract
# 138102              NaN                NaN
# 182254              NaN                NaN
# ...

# %%
df[["County", "City"]].value_counts()
# Out:
# County       City
# King         Seattle      33328
#              Bellevue     10234
#              Redmond       7341
# Clark        Vancouver     7286
# King         Kirkland      5998
#                           ...
# Whitman      Albion           1
#              Lacrosse         1
#              Lamont           1
#              Malden           1
# Walla Walla  Dixie            1
# Name: count, Length: 834, dtype: int64

# %%
df[pd.isna(df["County"]) | (df["Make"].isin(["BMW", "TESLA","CHEVROLET"]))][["County", "City"]].value_counts()
# Out:
# County        City
# King          Seattle      17191
#               Bellevue      7035
#               Redmond       4944
#               Sammamish     4188
#               Kirkland      3798
#                            ...
# Arapahoe      Aurora           1
# Adams         Aurora           1
# Anne Arundel  Hanover          1
# Yuba          Beale Afb        1
# Anne Arundel  Edgewater        1
# Name: count, Length: 686, dtype: int64

# %%
df[pd.isna(df["Base MSRP"]) | (df["Model"] == "S-CLASS")]
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 13273   W1K6G6KB0R  Snohomish       Everett    WA      98208.0        2024
# 18983   WDDUG6DB2F       King      Kirkland    WA      98034.0        2015
# 24480   WDDUG6DBXF      Clark         Camas    WA      98607.0        2015
# 29162   WDDUG6DB7H       King      Issaquah    WA      98029.0        2017
# 31588   W1K6G8CB9R       King    Des Moines    WA      98198.0        2024
# 35186   WDDUG6DB8H       King      Bellevue    WA      98006.0        2017
# 54121   WDDUG6DB7G       King       Seattle    WA      98103.0        2016
# 57148   W1K6G6KB8R       King      Kirkland    WA      98033.0        2024
# 60630   WDDUG6DB4H       King       Seattle    WA      98101.0        2017
# 62738   WDDUG6DB7H      Clark     Vancouver    WA      98683.0        2017
# 74028   W1K6G6KBXR       King       Seattle    WA      98117.0        2024
# ...
